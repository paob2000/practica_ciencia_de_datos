# %% [markdown]
# # PROYECTO EMPRESA ALIADA
# ## ENTREGABLE 4
# ## MODULO 33

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df_segmentos = pd.read_csv("segmentos2.csv")
df_ventas = pd.read_csv("ventas2.csv")

# %%
df_segmentos.sample(10)  # Copmenzamos dando una vista general de la data de estae data frame
# Out:
#     ID_CATEGORY        ATTR1             ATTR2                ATTR3   FORMAT  \
# 15            1   PRELAVADOR  FABRIC TREATMENT               BLANCO    POLVO
# 45            1  SAFE BLEACH  FABRIC TREATMENT           ROPA COLOR  LIQUIDO
# 41            1  SAFE BLEACH  FABRIC TREATMENT         QUITAMANCHAS  LIQUIDO
# 22            1   PRELAVADOR  FABRIC TREATMENT                 ROSA      GEL
# 30            1  SAFE BLEACH  FABRIC TREATMENT  COLOR PODER VINAGRE  LIQUIDO
# 39            1  SAFE BLEACH  FABRIC TREATMENT          PRE LAVADOR    POLVO
# 17            1   PRELAVADOR  FABRIC TREATMENT           OTR. TIPOS  LIQUIDO
# 50            1  SAFE BLEACH  FABRIC TREATMENT                 ROSA    POLVO
# 32            1  SAFE BLEACH  FABRIC TREATMENT           OTR. TIPOS      GEL
# 12            1        CLORO         MULTIUSOS            MULTIUSOS      GEL
#
#          SEGMENT                        CATEGORY
# 15        POWDER  FABRIC TREATMENT and SANIT\r\n
# ...

# %%
df_segmentos.shape  #De inicio es super imnportante saber con la cantidad de datos que vamos a trabajar
# Out:
# (53, 7)

# %%
df_segmentos["ID_CATEGORY"].unique()  #Luego de saber la cantidad de registros es importante determinar para las principales variables el numero de elementos unicos para saber como mostrarlos.
# Out:
# array([1], dtype=int64)

# %%
df_segmentos.info()  #Verificaamos con Info el tipo de data y si todos tienen la misma cantidad de información
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID_CATEGORY  53 non-null     int64
#  1   ATTR1        53 non-null     object
#  2   ATTR2        53 non-null     object
#  3   ATTR3        52 non-null     object
#  4   FORMAT       53 non-null     object
#  5   SEGMENT      53 non-null     object
#  6   CATEGORY     53 non-null     object
# dtypes: int64(1), object(6)
# memory usage: 3.0+ KB

# %%
#DATAFRAME DE VENTAS
df_ventas.sample(10)  #Verifico el tipo de datos general del Dataframe
# Out:
#          WEEK  YEAR  MONTH         ITEM_CODE  TOTAL_UNIT_SALES  \
# 109441  28-22  2022      7     7501080900141             0.979
# 113905  19-23  2023      5     0000075000622            39.368
# 53460   17-22  2022      5  7501058792808BP2             0.014
# 93508   01-22  2022      1     7501681100421             1.758
# 103696  32-22  2022      8     7501080900585             0.088
# 119198  21-23  2023      5     7501681100384             0.142
# 66831   09-22  2022      3     0757037517123             0.476
# 118093  24-23  2023      6     7501681100209             0.559
# 89365   25-22  2022      6     7501071904424             1.804
# 121734  21-23  2023      5     7501025412357             0.668
#
#         TOTAL_VALUE_SALES  TOTAL_UNIT_AVG_WEEKLY_SALES  \
# 109441             66.347                        3.117
# 113905            951.010                       97.446
# 53460               0.323                        1.750
# ...

# %%
df_ventas.shape #Vemos que vamos a trabajar con un número grande de ventas con 122002 registros
# Out:
# (122002, 8)

# %%
len(df_ventas["ITEM_CODE"].unique())  #Los productos puedes ser importantes para hacer un TOP de ventas, y aca nos damos cuenta que tenemos 350 productos para trabajar
# Out:
# 350

# %%
df_ventas.sort_values(by=['YEAR','MONTH']) # Aca constamos el rango de fechas de la data que es de Enero 2022 a Julio 2023
# Out:
#          WEEK  YEAR  MONTH         ITEM_CODE  TOTAL_UNIT_SALES  \
# 1151    03-22  2022      1     7702137007152             2.157
# 1152    03-22  2022      1     7702137007169             0.408
# 1153    03-22  2022      1     4008455425412             4.593
# 1154    03-22  2022      1     4008455460215             0.062
# 1155    03-22  2022      1     4008455457512             4.096
# ...       ...   ...    ...               ...               ...
# 121997  26-23  2023      7  7501058792778BP1             1.192
# 121998  26-23  2023      7     7501058757630             1.947
# 121999  26-23  2023      7     7501058753441            18.013
# 122000  26-23  2023      7  7702626204208BP1            21.152
# 122001  26-23  2023      7     7501058784346             1.468
#
#         TOTAL_VALUE_SALES  TOTAL_UNIT_AVG_WEEKLY_SALES  \
# 1151              129.456                        2.511
# 1152               25.027                        1.934
# ...

# %%
len(df_ventas["REGION"].unique()) # Este datos nos da el numero de regiones donde se vende, para entender mejor la segmentacion de los datos y ventas que vamos a presentar
# Out:
# 7

# %%
df_ventas.info()  # Este data frame se va a trabajar mucho y debemos tener preparados los tipos de datos, por lo que WEEK, ITEM_CODE y REGION los vamos a convertir en String
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122002 entries, 0 to 122001
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   WEEK                         122002 non-null  object
#  1   YEAR                         122002 non-null  int64
#  2   MONTH                        122002 non-null  int64
#  3   ITEM_CODE                    122002 non-null  object
#  4   TOTAL_UNIT_SALES             122002 non-null  float64
#  5   TOTAL_VALUE_SALES            122002 non-null  float64
#  6   TOTAL_UNIT_AVG_WEEKLY_SALES  122002 non-null  float64
#  7   REGION                       122002 non-null  object
# dtypes: float64(3), int64(2), object(3)
# memory usage: 7.4+ MB

# %%
#Proceso de cambio de tipo de datos
df_ventas['WEEK'] = df_ventas['WEEK'].astype("string")
df_ventas['ITEM_CODE'] = df_ventas['ITEM_CODE'].astype("string")
df_ventas['REGION'] = df_ventas['REGION'].astype("string")

df_ventas.info() #Ahora todos estan alineados con el tiempo de datos que realmente necesitan
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122002 entries, 0 to 122001
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   WEEK                         122002 non-null  string
#  1   YEAR                         122002 non-null  int64
#  2   MONTH                        122002 non-null  int64
#  3   ITEM_CODE                    122002 non-null  string
#  4   TOTAL_UNIT_SALES             122002 non-null  float64
#  5   TOTAL_VALUE_SALES            122002 non-null  float64
#  6   TOTAL_UNIT_AVG_WEEKLY_SALES  122002 non-null  float64
#  7   REGION                       122002 non-null  string
# dtypes: float64(3), int64(2), string(3)
# memory usage: 7.4 MB

# %%
df_ventas.describe() #Hacemos un analisis rápido, vemos consistencia en el numnero de registros, y nos damos cuenta un poco del comportamiento de los datos por variable
# Out:
#                 YEAR          MONTH  TOTAL_UNIT_SALES  TOTAL_VALUE_SALES  \
# count  122002.000000  122002.000000     122002.000000      122002.000000
# mean     2022.334396       5.531729          3.211097          90.513761
# std         0.471781       3.214612         14.496009         350.236505
# min      2022.000000       1.000000          0.000000           0.001000
# 25%      2022.000000       3.000000          0.063000           2.662000
# 50%      2022.000000       5.000000          0.367000          16.812000
# 75%      2023.000000       8.000000          1.520000          62.961500
# max      2023.000000      12.000000        504.681000       12236.759000
#
#        TOTAL_UNIT_AVG_WEEKLY_SALES
# count                122002.000000
# mean                     10.099904
# std                      22.650142
# min                       0.042000
# 25%                       2.316000
# 50%                       3.993500
# 75%                       8.898000
# ...

# %% [markdown]
# ![image.png](attachment:image.png)
#
#
# ## SEGMENTOS
#
# Verificando la información de este Dataframe vemos que solo podemos hacer un análisis de producción, es decir que es lo que hacen, porque no hay manera de cruzarlo con las ventas para ver alguna tendencia de negocio basados en el tipo de producto.
#
# Ya hablando a nivel de producción, solo podemos dar características pero no es posible determinar cuantitativamente cuanto se produce, ya que no tenemos esa información ni forma de ligarla tampoco a otra fuente de datos proporcionada.
#
# No se hará ningún análisis por categoría dado que el 100% de los registros son la misma categoría.
#
# Por tanto se va a elegir el SEGMENT que en este caso podría ser una subcategoría y un análisis básico por FORMAt, que nos puede de un indicio de el tipo de formato que se usa en los tipos de productos.
#
#
# ## VENTAS
#
# Este Dataset si tiene mayor información con 122,002 registros, y mucha información de valor para poder buscar hacer correlación.
#
# * Se van a trabajar set de datos por rangos de fechas usando los campos YEAR Y MONTH
# * Se va a ser un analisis de TOP de productos usando cantidad de unidades vendidas, ventas totales y distribución por regiones
# * Por tanto vamos igual a hacer un analisis de ticket promedio con el total de ventas y la unidades vendidas, y ver como se comportan el numero de unidades vendidas en promedio por semana
# * Finalmente vamos a ver el comportamiento de ventas por region

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# HISTOGRAMA DE VENTAS POR PRODUCTOS

# Agrupar las ventas totales por producto
ventas_por_producto = df_ventas.groupby('ITEM_CODE')['TOTAL_VALUE_SALES'].sum().reset_index()

# Configurar el estilo de seaborn
sns.set(style="whitegrid")

# Crear el histograma
plt.figure(figsize=(14, 7))
sns.histplot(data=ventas_por_producto, x='TOTAL_VALUE_SALES', bins=30, kde=True, color='blue')

# Personalizar la gráfica
plt.title('Distribución de Ventas por Producto', fontsize=14)
plt.xlabel('Ventas Totales ($)', fontsize=12)
plt.ylabel('Frecuencia de Productos', fontsize=12)
plt.grid(visible=True)

# Mostrar la gráfica
plt.tight_layout()
plt.savefig('Distribución de Ventas por Producto.jpg', format='jpg', dpi=300)
plt.show()

# %% [markdown]
# Partiendo de la información anterior donde sabemos que estamos trabajando con 350 productos, vemos como más de 300 producto estan en el primer rango entre 0 y 0,04, y casi toda la totalidad de produtos en el rango de 0,12, lo que concentra de gran manera un ticket promedio muy similar y vuelve todos los productos bastantes competitivos a nivel precio, entre ellos mismos.

# %%
# AHORA IDENTIFIQUES EL TOP 10 DE LOS PRODUCTOS MAS VENDIDOS

# Agrupar las unidades vendidas totales por producto
ventas_por_producto = df_ventas.groupby('ITEM_CODE')['TOTAL_UNIT_SALES'].sum().reset_index()

# Ordenar los productos por cantidad de unidades vendidas en orden descendente
ventas_por_producto = ventas_por_producto.sort_values(by='TOTAL_UNIT_SALES', ascending=False)

# Seleccionar el Top 10 de productos
top_10_productos = ventas_por_producto.head(10)

# Configurar el estilo de seaborn
sns.set(style="whitegrid")

# Crear el gráfico de barras
plt.figure(figsize=(14, 7))
sns.barplot(data=top_10_productos, x='TOTAL_UNIT_SALES', y='ITEM_CODE', palette='viridis')

# Personalizar la gráfica
plt.title('Top 10 Productos Más Vendidos (Unidades Totales)', fontsize=14)
plt.xlabel('Cantidad de Unidades Vendidas', fontsize=12)
plt.ylabel('Código del Producto', fontsize=12)
plt.grid(visible=True)

# Mostrar la gráfica
plt.tight_layout()
plt.savefig('Top 10 Productos Más Vendidos (Unidades Totales).jpg', format='jpg', dpi=300)
plt.show()
# Out:
# C:\Users\paob2\AppData\Local\Temp\ipykernel_17268\2009364462.py:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top_10_productos, x='TOTAL_UNIT_SALES', y='ITEM_CODE', palette='viridis')

# %% [markdown]
# Este TOP 10 de producto nos da una idea, de que a pesar de que vimos que todos los productos puede competir fácilmente dentro de un rango de precio similar, hay productos super ganadores  que casi quintuplican las ventas de los puestos 8 al 10 de los 350 productos, Esto quiere decir que probablemente la economía de la empresa se está basando en muy pocos productos que le dan éxito y quizas hay una gran cantidad de productos que no se venden y podrían estar generando costos de producción. Aunque de igual manera depender de un par de productos para el éxico de la compañía podría ser demasiado peligroso, por lo que hacer un análisis incluyendo el tipo de producto, subcategorias y segmentos de compradores podría ser muy valioso para crear más productos ganadores.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# TOTAL VENTAS POR MES

# Crear una columna combinada de Año-Mes para un mejor análisis
df_ventas['YEAR_MONTH'] = pd.to_datetime(df_ventas[['YEAR', 'MONTH']].assign(DAY=1))

# Agrupar las ventas totales por mes
ventas_mensuales = df_ventas.groupby('YEAR_MONTH')['TOTAL_VALUE_SALES'].sum().reset_index()

# Configurar estilo de seaborn
sns.set(style="whitegrid")

# Crear la gráfica
plt.figure(figsize=(12, 6))
sns.lineplot(data=ventas_mensuales, x='YEAR_MONTH', y='TOTAL_VALUE_SALES', marker='o', color='b')

# Personalizar la gráfica
plt.title('Ventas Totales por Mes (Enero 2022 - Julio 2023)', fontsize=14)
plt.xlabel('Fecha (Año-Mes)', fontsize=12)
plt.ylabel('Ventas Totales ($)', fontsize=12)
plt.xticks(rotation=45)
plt.grid(visible=True)

# Mostrar la gráfica
plt.tight_layout()
plt.savefig('Ventas Totales por Mes (Enero 2022 - Julio 2023).jpg', format='jpg', dpi=300)
plt.show()

# %% [markdown]
# Este grafico de ventas a través del tiempo nos indica varias cosas importantes.
#
# 1. Hay una gran variabilidad de ventas mes a mes, lo que es importante para los presupeustos de la empresa, porque seguramente la caja se mueve con rangos muy altos de un mes a otro.
# 2. Cuando observamos meses iguales de un año a otro, aunque las ventas no son iguales, sí son similares los comportamientos, lo que con mas data a través del tiempo nos podría indicar una constancia en la variabilidad de ventas de un mes a otro con mayor exactitud.
# 3.  Mayo y Julio podrían considerarse meses de mucha importancia para las ventas de la empresa.

# %%
# TOTAL UNIDADES VENDADS POR MES POR MES


# Agrupar las ventas totales por mes
unidades_mensuales = df_ventas.groupby('YEAR_MONTH')['TOTAL_UNIT_SALES'].sum().reset_index()

# Configurar estilo de seaborn
sns.set(style="whitegrid")

# Crear la gráfica
plt.figure(figsize=(12, 6))
sns.lineplot(data=unidades_mensuales, x='YEAR_MONTH', y='TOTAL_UNIT_SALES', marker='o', color='b')

# Personalizar la gráfica
plt.title('Unidades Vendidas por Mes (Enero 2022 - Julio 2023)', fontsize=14)
plt.xlabel('Fecha (Año-Mes)', fontsize=12)
plt.ylabel('Unidades Vendidas', fontsize=12)
plt.xticks(rotation=45)
plt.grid(visible=True)

# Mostrar la gráfica
plt.tight_layout()
plt.savefig('Unidades Vendidas por Mes (Enero 2022 - Julio 2023).jpg', format='jpg', dpi=300)
plt.show()

# %% [markdown]
# Esta gráfica de unidades vendidas a través del tiempo confirma varios temas que ya se han venido hablando.  Al tener un ticket tan similar entre productos, no hace mucho la diferencia cuando hablamos en cantidades, ya que todos son muy parecidos en precio.  Es por esta razón que la gráfica casi que se puede super poner con la anterior porque los números en proporción son muy parecedios entre las unidades vendidas y las ventas totales por mes.

# %%
import matplotlib.pyplot as plt
import seaborn as sns


# Agrupar las ventas totales por región y mes
ventas_por_region_tiempo = df_ventas.groupby(['YEAR_MONTH', 'REGION'])['TOTAL_VALUE_SALES'].sum().reset_index()

# Configurar estilo de seaborn
sns.set(style="whitegrid")

# Crear la gráfica de líneas
plt.figure(figsize=(16, 8))
sns.lineplot(data=ventas_por_region_tiempo, x='YEAR_MONTH', y='TOTAL_VALUE_SALES', hue='REGION', marker='o', palette='tab10')

# Personalizar la gráfica
plt.title('Total de Ventas por Región a Través del Tiempo', fontsize=16)
plt.xlabel('Fecha (Año-Mes)', fontsize=14)
plt.ylabel('Ventas Totales ($)', fontsize=14)
plt.xticks(rotation=45)
plt.legend(title='Región', fontsize=12, title_fontsize=14)
plt.grid(visible=True)

# Ajustar el diseño y mostrar la gráfica
plt.tight_layout()
plt.savefig('Total de Ventas por Región a Través del Tiempo.jpg', format='jpg', dpi=300)
plt.show()

# %% [markdown]
# Las ventas por región, vemos que están distribuidas en 7 regiones, 6 de ellas con un numeral por área y la última llamada scanning México.  No es claro si Scanning México sea la totalización de las demás áreas (que es probable) y las demás areas estén distribuidas a lo largo de todo México.  Lo que es cierto es que el comportamiento por área es muy similar, no hay super valores que cambien la tendendica de una manera transcendental.  Por otro lado la gráfica de Scanning Méxio puede ser exponencial porque si es un área importnate por ejemplo todo el Estado de Mëxico que casi multimplica por 6 las demás areas.  Por eso puede ser un valor total, pero esta informaçión no fue suministrada.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# REALACION ENTRE TOTAL_UNIT_SALES Y TOTAL_VALUE_SALES POR REGION

# Configurar estilo de seaborn
sns.set(style="whitegrid")

# Crear el gráfico de dispersión
plt.figure(figsize=(10, 6))
sns.scatterplot(
    data=df_ventas,
    x='TOTAL_UNIT_SALES',
    y='TOTAL_VALUE_SALES',
    hue='REGION',
    palette='tab10',
    alpha=0.7
)

# Personalizar la gráfica
plt.title('Relación entre Unidades Vendidas y Ventas Totales por Región', fontsize=14)
plt.xlabel('Total de Unidades Vendidas', fontsize=12)
plt.ylabel('Total de Ventas ($)', fontsize=12)
plt.legend(title='Región', fontsize=10, title_fontsize=12)
plt.grid(visible=True)

# Mostrar la gráfica
plt.tight_layout()
plt.savefig('Relación entre Unidades Vendidas y Ventas Totales por Región.jpg', format='jpg', dpi=300)
plt.show()

# %% [markdown]
# Estas gráficas de scatter son excelentes para ver gráficamente correlaciones, y en definitva las unidades vendidas van fuertemente atadas a las ventas totales, y esto se debe mucho a que el ticket promedio entre todas las regiones es muy similar de manera positiva como lo indica el desarrollo de la gráfica.

# %%
# RELACION ENTRE TOTAL_UNIT_AVG_WEEKLYU_SALES Y TOTAL_UNIT_SALES POR REGION

# Crear el gráfico de dispersión
plt.figure(figsize=(10, 6))
sns.scatterplot(
    data=df_ventas,
    x='TOTAL_UNIT_AVG_WEEKLY_SALES',
    y='TOTAL_UNIT_SALES',
    hue='REGION',
    palette='cool',
    alpha=0.7
)

# Personalizar la gráfica
plt.title('Relación entre Ventas Promedio Semanales y Total de Unidades Vendidas', fontsize=14)
plt.xlabel('Ventas Promedio Semanales (Unidades)', fontsize=12)
plt.ylabel('Total de Unidades Vendidas', fontsize=12)
plt.legend(title='Región', fontsize=10, title_fontsize=12)
plt.grid(visible=True)

# Mostrar la gráfica
plt.tight_layout()
plt.savefig('Relación entre Ventas Promedio Semanales y Total de Unidades Vendidas.jpg', format='jpg', dpi=300)
plt.show()

# %% [markdown]
# Esta correlación entre ventas promedio semanales y total de unidades vendidas  al final debe de ser coincidente porque comparten el comportamiento, pero podemos ver la diferencia que hay entre las áreas y como la correlación puede ser mas positiva que otra.

# %%
# RELACION ENTRE TOTAL_UNIT_AVG_WEEKLYU_SALES Y TOTAL_VALUE_SALES POR REGION

# Crear el gráfico de dispersión
plt.figure(figsize=(10, 6))
sns.scatterplot(
    data=df_ventas,
    x='TOTAL_UNIT_AVG_WEEKLY_SALES',
    y='TOTAL_VALUE_SALES',
    hue='REGION',
    palette='muted',
    alpha=0.7
)

# Personalizar la gráfica
plt.title('Relación entre Ventas Totales y Ventas Promedio Semanales', fontsize=14)
plt.xlabel('Ventas Promedio Semanales (Unidades)', fontsize=12)
plt.ylabel('Ventas Totales ($)', fontsize=12)
plt.legend(title='Región', fontsize=10, title_fontsize=12)
plt.grid(visible=True)

# Mostrar la gráfica
plt.tight_layout()
plt.savefig('Relación entre Ventas Totales y Ventas Promedio Semanales.jpg', format='jpg', dpi=300)
plt.show()

# %% [markdown]
# Al igual que la correlación anterior, de antemano esperamos que sí se de una correlación entre las ventas totales y el promedio de unidades semanales vendidas, pero lo importante es ver la diferencición que existe entre las diferentes regiones.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# GRAFICO DE BARRAS APLILADAS APRA VENTAS POR REGION Y MES

# Agrupar las ventas totales por región y mes
ventas_por_region_mes = df_ventas.groupby(['YEAR_MONTH', 'REGION'])['TOTAL_VALUE_SALES'].sum().unstack()

# Crear el gráfico de barras apiladas
ventas_por_region_mes.plot(kind='bar', stacked=True, figsize=(14, 8), colormap='tab20c')

# Personalizar la gráfica
plt.title('Ventas Totales por Región y Mes', fontsize=16)
plt.xlabel('Mes (Año-Mes)', fontsize=12)
plt.ylabel('Ventas Totales ($)', fontsize=12)
plt.legend(title='Región', fontsize=10, title_fontsize=12)
plt.xticks(rotation=45)
plt.grid(axis='y')

# Mostrar la gráfica
plt.tight_layout()
plt.savefig('Ventas Totales por Región y Mes.jpg', format='jpg', dpi=300)
plt.show()

# %% [markdown]
# En esta gráfica podemos ver mucho más facil una combinación muy especial entre uno de los primeros gráficos de línea donde se ve el comportamiento de ventas mes a mes, pero esta vez con una distribución por región, que a la vez nos va confirmando que el Scanning Mexico es la suma de todas las áreas, ya que es el doble de cada una de las medidas.
#
# Visualmente casi podemos asegurar que al area con mayor variabilidad dee precios es el área 2 y que puede estar compitiendo con el parea 5 con las mayores ventas por región.

# %%
# GRAFICO DE VENTAS TOTALES POR REGION

# Agrupar las ventas totales por región
ventas_por_region = df_ventas.groupby('REGION')['TOTAL_VALUE_SALES'].sum().sort_values()

# Crear el gráfico de barras horizontales
plt.figure(figsize=(10, 6))
sns.barplot(
    x=ventas_por_region.values,
    y=ventas_por_region.index,
    palette='viridis'
)

# Personalizar la gráfica
plt.title('Ventas Totales por Región', fontsize=16)
plt.xlabel('Ventas Totales ($)', fontsize=14)
plt.ylabel('Región', fontsize=14)
plt.grid(axis='x', linestyle='--', alpha=0.7)

# Mostrar la gráfica
plt.tight_layout()
plt.savefig('Ventas Totales por Región.jpg', format='jpg', dpi=300)
plt.show()
# Out:
# C:\Users\paob2\AppData\Local\Temp\ipykernel_17268\2469971300.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %% [markdown]
# Para confirmar de manera mas clara, el tema de mejores ventas por región, esta gráfica ya nos da una mejor vista, y en efecto el área 2 compite muy de cerca con el área 5 con las mejores ventas en todo México y las dos áres que menos venden con la 4 y la 1.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# VENTAS POR PRODUCTO TOP 20

# Agrupar las ventas por producto y ordenar por ventas totales
top_productos = df_ventas.groupby('ITEM_CODE')['TOTAL_VALUE_SALES'].sum().sort_values(ascending=False).head(20)

# Filtrar el DataFrame para incluir solo los productos top
df_top_productos = df_ventas[df_ventas['ITEM_CODE'].isin(top_productos.index)]

# Crear el gráfico de caja para los top 20 productos
plt.figure(figsize=(14, 8))
sns.boxplot(
    data=df_top_productos,
    x='TOTAL_VALUE_SALES',
    y='ITEM_CODE',
    palette='coolwarm',
    showfliers=True
)

# Personalizar la gráfica
plt.title('Distribución de Ventas Totales de los Top 20 Productos', fontsize=16)
plt.xlabel('Ventas Totales ($)', fontsize=12)
plt.ylabel('Código del Producto', fontsize=12)
plt.grid(visible=True, axis='x', linestyle='--', alpha=0.7)

# Mostrar la gráfica
plt.tight_layout()
plt.savefig('Distribución de Ventas Totales de los Top 20 Productos.jpg', format='jpg', dpi=300)
plt.show()
# Out:
# C:\Users\paob2\AppData\Local\Temp\ipykernel_17268\3870920895.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(

# %% [markdown]
# Realizar una distribución con 350 productos es realmente bastante difícil, pero cuando hacenos los ranking podemos ver comportanmientos bien interesantes.  Al inicio vimos que los rangos de precios son bastante similares, y también vimos que solo unos pocos productos son los que mas se venden y realmente generan los números en la compañía.
#
# Viendo de cerca el comportamiento de los 20 productos más vendidos respecto al total de ventas, que tiene un comportamiento típico en general desde 0 a 1000, y unos pocos se suben hasta 2400 con su venta máxima, pero al final del dia se generan muchos valores atípicos conocidos como outliers que suben las ventas en gran magnitud.  Especialmente emos estos 3 productos en el medio con valores muy distiantes del máximo.
#
# ![](attachment:image.png)
#
# Esta conducta podría afirmar como mencioné anteriormente que son productos estrella, y que se depende de ellos para el éxito del negocio.  Otras razones pueden tambien ser promociones especiales constantes,  picos estacionales o bien que tengamos algún error en los datos.
#
# En cuanto al tema de no tener outliers del lado izquierdo en estos productos, muestra una demanda constante, que hay una satisfacción mínima de la demanda, y que se está dando una buena gestión de inventarios y precios para estos productos.

# %%
# VENTAS POR REGION

# Crear el gráfico de caja para identificar outliers por región
plt.figure(figsize=(12, 6))
sns.boxplot(
    data=df_ventas,
    x='TOTAL_VALUE_SALES',
    y='REGION',
    palette='viridis',
    showfliers=True
)

# Personalizar la gráfica
plt.title('Distribución de Ventas Totales por Región', fontsize=16)
plt.xlabel('Ventas Totales ($)', fontsize=12)
plt.ylabel('Región', fontsize=12)
plt.grid(visible=True, axis='x', linestyle='--', alpha=0.7)

# Mostrar la gráfica
plt.tight_layout()
plt.savefig('Distribución de Ventas Totales por Región.jpg', format='jpg', dpi=300)
plt.show()
# Out:
# C:\Users\paob2\AppData\Local\Temp\ipykernel_17268\1446880616.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(

# %% [markdown]
# Esta gráfica de distribución por Región, tiene un comportamiento similar que podemos leer de la misma forma que el gráfico anterior.
#
# No obstante, obvianto el Scanning México que ahora aceptamos con las ventas totales,  vemos ya que entre las Areas, el cuerpo de la gráfica tiene un rango, mínmo, máximo y media muy similares, al igual que los outliers, aunque estos ya tienen un poco más de diferencia.

# %%
# PROMEDIO DE VENTAS SEMANALES POR REGION

# Crear el gráfico de caja para identificar outliers en ventas promedio semanales
plt.figure(figsize=(12, 6))
sns.boxplot(
    data=df_ventas,
    x='TOTAL_UNIT_AVG_WEEKLY_SALES',
    y='REGION',
    palette='cubehelix',
    showfliers=True
)

# Personalizar la gráfica
plt.title('Distribución de Ventas Promedio Semanales por Región', fontsize=16)
plt.xlabel('Ventas Promedio Semanales (Unidades)', fontsize=12)
plt.ylabel('Región', fontsize=12)
plt.grid(visible=True, axis='x', linestyle='--', alpha=0.7)

# Mostrar la gráfica
plt.tight_layout()
plt.savefig('Distribución de Ventas Promedio Semanales por Región.jpg', format='jpg', dpi=300)
plt.show()
# Out:
# C:\Users\paob2\AppData\Local\Temp\ipykernel_17268\4011669474.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Se han realizado al pie de cada gráfico
